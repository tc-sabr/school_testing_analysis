# %%
#dependencies
import pandas as pd

# %%
#create file paths
raw_school_data = "Resources/schools_complete.csv"
raw_student_data = "Resources/students_complete.csv"

# %%
#put raw data in dataframe
school_df = pd.read_csv(raw_school_data)
student_df = pd.read_csv(raw_student_data)

# %%
#show school dataframe
school_df.head()
# Out:
#    School ID            school_name      type  size   budget
# 0          0      Huang High School  District  2917  1910635
# 1          1   Figueroa High School  District  2949  1884411
# 2          2    Shelton High School   Charter  1761  1056600
# 3          3  Hernandez High School  District  4635  3022020
# 4          4    Griffin High School   Charter  1468   917500

# %%
#show student dataframe 
student_df.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score
# 0             66          79
# 1             94          61
# 2             90          60
# 3             67          58
# 4             97          84

# %%
merge_school_student = pd.merge(school_df, student_df, on='school_name')
merge_school_student.head()
# Out:
#    School ID        school_name      type  size   budget  Student ID  \
# 0          0  Huang High School  District  2917  1910635           0
# 1          0  Huang High School  District  2917  1910635           1
# 2          0  Huang High School  District  2917  1910635           2
# 3          0  Huang High School  District  2917  1910635           3
# 4          0  Huang High School  District  2917  1910635           4
#
#         student_name gender grade  reading_score  math_score
# 0       Paul Bradley      M   9th             66          79
# 1       Victor Smith      M  12th             94          61
# 2    Kevin Rodriguez      M  12th             90          60
# 3  Dr. Richard Scott      M  12th             67          58
# 4         Bonnie Ray      F   9th             97          84

# %%
#rename columns
renamed_columns = merge_school_student.rename(columns={'school_name': 'School Name', 'type': 'School Type',
                                                       'size': 'School Size', 'budget': 'School Budget',
                                                       'student_name': 'Student Name', 'gender': 'Gender',
                                                       'grade': 'Grade', 'reading_score': 'Reading Score', 
                                                       'math_score':'Math Score'})
renamed_columns.head()
# Out:
#    School ID        School Name School Type  School Size  School Budget  \
# 0          0  Huang High School    District         2917        1910635
# 1          0  Huang High School    District         2917        1910635
# 2          0  Huang High School    District         2917        1910635
# 3          0  Huang High School    District         2917        1910635
# 4          0  Huang High School    District         2917        1910635
#
#    Student ID       Student Name Gender Grade  Reading Score  Math Score
# 0           0       Paul Bradley      M   9th             66          79
# 1           1       Victor Smith      M  12th             94          61
# 2           2    Kevin Rodriguez      M  12th             90          60
# 3           3  Dr. Richard Scott      M  12th             67          58
# 4           4         Bonnie Ray      F   9th             97          84

# %%
#count schools
unique_schools = renamed_columns['School Name'].nunique()
unique_schools
# Out:
# 15

# %%
#calculate students in district
district_student = school_df['size'].sum()
district_student
# Out:
# 39170

# %%
#calculate district budget
district_budget = school_df['budget'].sum()
district_budget
# Out:
# 24649428

# %%
#calculate district avg math score
dist_avg_math = renamed_columns['Math Score'].mean()
dist_avg_math
# Out:
# 78.98537145774827

# %%
#calculate district avg reading score
dist_avg_reading = renamed_columns['Reading Score'].mean()
dist_avg_reading
# Out:
# 81.87784018381414

# %%
#calculate district percentage passing math
dist_pass_math = (renamed_columns[renamed_columns['Math Score'] >= 70].count()['Student Name'] * 100) / district_student
dist_pass_math
# Out:
# 74.9808526933878

# %%
#calculate district percentage passing reading
dist_pass_reading = (renamed_columns[renamed_columns['Reading Score'] >= 70].count()['Student Name'] * 100) / district_student
dist_pass_reading
# Out:
# 85.80546336482001

# %%
#calculate district overall passing
dist_pass_overall = (dist_pass_math + dist_pass_reading) / 2
dist_pass_overall
# Out:
# 80.39315802910392

# %%
#district summary dataframe
district_data = [{'Total Schools': unique_schools, 'Total Students': district_student, 'Total Budget': district_budget, 
                     'Average Math Score': dist_avg_math, 'Average Reading Score': dist_avg_reading, 
                     '% Passing Math': dist_pass_math, '% Passing Reading': dist_pass_reading, 
                     '% Overall Passing': dist_pass_overall}]

district_summary = pd.DataFrame(district_data)
district_summary
# Out:
#    % Overall Passing  % Passing Math  % Passing Reading  Average Math Score  \
# 0          80.393158       74.980853          85.805463           78.985371
#
#    Average Reading Score  Total Budget  Total Schools  Total Students
# 0               81.87784      24649428             15           39170

# %%
#reorganize summary to make sense
reorganized_district_summary = district_summary[['Total Schools', 'Total Students', 'Total Budget', 
                                                 'Average Math Score', 'Average Reading Score', 
                                                 '% Passing Math', '% Passing Reading', '% Overall Passing']]

reorganized_district_summary
# Out:
#    Total Schools  Total Students  Total Budget  Average Math Score  \
# 0             15           39170      24649428           78.985371
#
#    Average Reading Score  % Passing Math  % Passing Reading  % Overall Passing
# 0               81.87784       74.980853          85.805463          80.393158

# %%
#format district summary table
reorganized_district_summary['Total Students'] = reorganized_district_summary['Total Students'].map('{:,}'.format)
reorganized_district_summary['Total Budget'] = reorganized_district_summary['Total Budget'].map('${:,}'.format)
reorganized_district_summary['Average Math Score'] = reorganized_district_summary['Average Math Score'].map('{:.2f}'.format)
reorganized_district_summary['Average Reading Score'] = reorganized_district_summary['Average Reading Score'].map('{:.2f}'.format)
reorganized_district_summary['% Passing Math'] = reorganized_district_summary['% Passing Math'].map('{:.2f}%'.format)
reorganized_district_summary['% Passing Reading'] = reorganized_district_summary['% Passing Reading'].map('{:.2f}%'.format)
reorganized_district_summary['% Overall Passing'] = reorganized_district_summary['% Overall Passing'].map('{:.2f}%'.format)

reorganized_district_summary
# Out:
#    Total Schools Total Students Total Budget Average Math Score  \
# 0             15         39,170  $24,649,428              78.99
#
#   Average Reading Score % Passing Math % Passing Reading % Overall Passing
# 0                 81.88         74.98%            85.81%            80.39%

# %%
#group by school name
grouped_school = renamed_columns.groupby(['School Name'])

avg_scores = grouped_school.mean()

avg_scores.head()
# Out:
#                       School ID  School Size  School Budget  Student ID  \
# School Name
# Bailey High School          7.0       4976.0      3124928.0     20358.5
# Cabrera High School         6.0       1858.0      1081356.0     16941.5
# Figueroa High School        1.0       2949.0      1884411.0      4391.0
# Ford High School           13.0       2739.0      1763916.0     36165.0
# Griffin High School         4.0       1468.0       917500.0     12995.5
#
#                       Reading Score  Math Score
# School Name
# Bailey High School        81.033963   77.048432
# Cabrera High School       83.975780   83.061895
# Figueroa High School      81.158020   76.711767
# Ford High School          80.746258   77.102592
# Griffin High School       83.816757   83.351499

# %%
#count students per school
sch_students = renamed_columns['School Name'].value_counts()

sch_students
# Out:
# Bailey High School       4976
# Johnson High School      4761
# Hernandez High School    4635
# Rodriguez High School    3999
# Figueroa High School     2949
# Huang High School        2917
# Ford High School         2739
# Wilson High School       2283
# Cabrera High School      1858
# Wright High School       1800
# Shelton High School      1761
# Thomas High School       1635
# Griffin High School      1468
# Pena High School          962
# Holden High School        427
# Name: School Name, dtype: int64

# %%
#each school budget
sch_budget = grouped_school['School Budget'].sum() / sch_students

sch_budget
# Out:
# Bailey High School       3124928.0
# Cabrera High School      1081356.0
# Figueroa High School     1884411.0
# Ford High School         1763916.0
# Griffin High School       917500.0
# Hernandez High School    3022020.0
# Holden High School        248087.0
# Huang High School        1910635.0
# Johnson High School      3094650.0
# Pena High School          585858.0
# Rodriguez High School    2547363.0
# Shelton High School      1056600.0
# Thomas High School       1043130.0
# Wilson High School       1319574.0
# Wright High School       1049400.0
# dtype: float64

# %%
#calculate per student budget per school
sch_student_budget = sch_budget / sch_students

sch_student_budget
# Out:
# Bailey High School       628.0
# Cabrera High School      582.0
# Figueroa High School     639.0
# Ford High School         644.0
# Griffin High School      625.0
# Hernandez High School    652.0
# Holden High School       581.0
# Huang High School        655.0
# Johnson High School      650.0
# Pena High School         609.0
# Rodriguez High School    637.0
# Shelton High School      600.0
# Thomas High School       638.0
# Wilson High School       578.0
# Wright High School       583.0
# dtype: float64

# %%
#calculate school % passing math
sch_pass_math = (renamed_columns[renamed_columns['Math Score'] >= 70].groupby('School Name')['Math Score'].count()) * 100 / sch_students
sch_pass_math
# Out:
# Bailey High School       66.680064
# Cabrera High School      94.133477
# Figueroa High School     65.988471
# Ford High School         68.309602
# Griffin High School      93.392371
# Hernandez High School    66.752967
# Holden High School       92.505855
# Huang High School        65.683922
# Johnson High School      66.057551
# Pena High School         94.594595
# Rodriguez High School    66.366592
# Shelton High School      93.867121
# Thomas High School       93.272171
# Wilson High School       93.867718
# Wright High School       93.333333
# dtype: float64

# %%
#calculate school % passing reading
sch_pass_reading = (renamed_columns[renamed_columns['Reading Score'] >= 70].groupby('School Name')['Reading Score'].count()) * 100 / sch_students
sch_pass_reading
# Out:
# Bailey High School       81.933280
# Cabrera High School      97.039828
# Figueroa High School     80.739234
# Ford High School         79.299014
# Griffin High School      97.138965
# Hernandez High School    80.862999
# Holden High School       96.252927
# Huang High School        81.316421
# Johnson High School      81.222432
# Pena High School         95.945946
# Rodriguez High School    80.220055
# Shelton High School      95.854628
# Thomas High School       97.308869
# Wilson High School       96.539641
# Wright High School       96.611111
# dtype: float64

# %%
#calculate school % overall passing
sch_pass_overall = (sch_pass_math + sch_pass_reading) / 2
sch_pass_overall
# Out:
# Bailey High School       74.306672
# Cabrera High School      95.586652
# Figueroa High School     73.363852
# Ford High School         73.804308
# Griffin High School      95.265668
# Hernandez High School    73.807983
# Holden High School       94.379391
# Huang High School        73.500171
# Johnson High School      73.639992
# Pena High School         95.270270
# Rodriguez High School    73.293323
# Shelton High School      94.860875
# Thomas High School       95.290520
# Wilson High School       95.203679
# Wright High School       94.972222
# dtype: float64

# %%
#capture school avg math & reading scores
math_reading_scores = avg_scores.loc[:,['Math Score', 'Reading Score']]
math_reading_scores
# Out:
#                        Math Score  Reading Score
# School Name
# Bailey High School      77.048432      81.033963
# Cabrera High School     83.061895      83.975780
# Figueroa High School    76.711767      81.158020
# Ford High School        77.102592      80.746258
# Griffin High School     83.351499      83.816757
# Hernandez High School   77.289752      80.934412
# Holden High School      83.803279      83.814988
# Huang High School       76.629414      81.182722
# Johnson High School     77.072464      80.966394
# Pena High School        83.839917      84.044699
# Rodriguez High School   76.842711      80.744686
# Shelton High School     83.359455      83.725724
# Thomas High School      83.418349      83.848930
# Wilson High School      83.274201      83.989488
# Wright High School      83.682222      83.955000

# %%
#rename math and reading column
raw_school_summary = math_reading_scores.rename(columns={'Math Score': 'Average Math Score', 
                                                         'Reading Score': 'Average Reading Score'})

raw_school_summary.head()
# Out:
#                       Average Math Score  Average Reading Score
# School Name
# Bailey High School             77.048432              81.033963
# Cabrera High School            83.061895              83.975780
# Figueroa High School           76.711767              81.158020
# Ford High School               77.102592              80.746258
# Griffin High School            83.351499              83.816757

# %%
#capture school type
raw_sch_type = school_df.loc[:,['school_name', 'type']]

sch_type.head()
# Out:
#                            type
# School Name
# Huang High School      District
# Figueroa High School   District
# Shelton High School     Charter
# Hernandez High School  District
# Griffin High School     Charter

# %%
#rename and set index to school name
renamed_raw_sch_type = raw_sch_type.rename(columns={'school_name': 'School Name'})

sch_type = renamed_raw_sch_type.set_index('School Name')

sch_type.head()
# Out:
#                            type
# School Name
# Huang High School      District
# Figueroa High School   District
# Shelton High School     Charter
# Hernandez High School  District
# Griffin High School     Charter

# %%
#create school summary dataframe
raw_school_summary['Total Students'] = sch_students
raw_school_summary['Total Budget'] = sch_budget
raw_school_summary['Per Student Budget'] = sch_student_budget
raw_school_summary['% Passing Math'] = sch_pass_math
raw_school_summary['% Passing Reading'] = sch_pass_reading
raw_school_summary['% Overall Passing'] = sch_pass_overall
raw_school_summary['School Type'] = sch_type

raw_school_summary.head()
# Out:
#                       Average Math Score  Average Reading Score  \
# School Name
# Bailey High School             77.048432              81.033963
# Cabrera High School            83.061895              83.975780
# Figueroa High School           76.711767              81.158020
# Ford High School               77.102592              80.746258
# Griffin High School            83.351499              83.816757
#
#                       Total Students  Total Budget  Per Student Budget  \
# School Name
# Bailey High School              4976     3124928.0               628.0
# Cabrera High School             1858     1081356.0               582.0
# Figueroa High School            2949     1884411.0               639.0
# Ford High School                2739     1763916.0               644.0
# Griffin High School             1468      917500.0               625.0
#
#                       % Passing Math  % Passing Reading  % Overall Passing  \
# School Name
# ...

# %%
#reorganize df to make sense
school_summary = raw_school_summary[['School Type', 'Total Students', 'Total Budget', 
                                     'Per Student Budget','Average Math Score', 'Average Reading Score', 
                                     '% Passing Math', '% Passing Reading', '% Overall Passing']]

school_summary.head()
# Out:
#                      School Type  Total Students  Total Budget  \
# School Name
# Bailey High School      District            4976     3124928.0
# Cabrera High School      Charter            1858     1081356.0
# Figueroa High School    District            2949     1884411.0
# Ford High School        District            2739     1763916.0
# Griffin High School      Charter            1468      917500.0
#
#                       Per Student Budget  Average Math Score  \
# School Name
# Bailey High School                 628.0           77.048432
# Cabrera High School                582.0           83.061895
# Figueroa High School               639.0           76.711767
# Ford High School                   644.0           77.102592
# Griffin High School                625.0           83.351499
#
#                       Average Reading Score  % Passing Math  \
# School Name
# Bailey High School                81.033963       66.680064
# ...

# %%
#format columns
school_summary['Total Students'] = school_summary['Total Students'].map('{:,}'.format)
school_summary['Total Budget'] = school_summary['Total Budget'].map('${:,.2f}'.format)
school_summary['Per Student Budget'] = school_summary['Per Student Budget'].map('${:,.2f}'.format)
school_summary['Average Math Score'] = school_summary['Average Math Score'].map('{:.2f}'.format)
school_summary['Average Reading Score'] = school_summary['Average Reading Score'].map('{:.2f}'.format)
school_summary['% Passing Math'] = school_summary['% Passing Math'].map('{:.2f}%'.format)
school_summary['% Passing Reading'] = school_summary['% Passing Reading'].map('{:.2f}%'.format)
school_summary['% Overall Passing'] = school_summary['% Overall Passing'].map('{:.2f}%'.format)

school_summary
# Out:
#                       School Type Total Students   Total Budget  \
# School Name
# Bailey High School       District          4,976  $3,124,928.00
# Cabrera High School       Charter          1,858  $1,081,356.00
# Figueroa High School     District          2,949  $1,884,411.00
# Ford High School         District          2,739  $1,763,916.00
# Griffin High School       Charter          1,468    $917,500.00
# Hernandez High School    District          4,635  $3,022,020.00
# Holden High School        Charter            427    $248,087.00
# Huang High School        District          2,917  $1,910,635.00
# Johnson High School      District          4,761  $3,094,650.00
# Pena High School          Charter            962    $585,858.00
# Rodriguez High School    District          3,999  $2,547,363.00
# Shelton High School       Charter          1,761  $1,056,600.00
# Thomas High School        Charter          1,635  $1,043,130.00
# ...

# %%
#top 5 performing schools based on overall passing rate
top_performers = school_summary.sort_values('% Overall Passing', ascending=False)

top_performers.head()
# Out:
#                     School Type Total Students   Total Budget  \
# School Name
# Cabrera High School     Charter          1,858  $1,081,356.00
# Thomas High School      Charter          1,635  $1,043,130.00
# Griffin High School     Charter          1,468    $917,500.00
# Pena High School        Charter            962    $585,858.00
# Wilson High School      Charter          2,283  $1,319,574.00
#
#                     Per Student Budget Average Math Score  \
# School Name
# Cabrera High School            $582.00              83.06
# Thomas High School             $638.00              83.42
# Griffin High School            $625.00              83.35
# Pena High School               $609.00              83.84
# Wilson High School             $578.00              83.27
#
#                     Average Reading Score % Passing Math % Passing Reading  \
# School Name
# Cabrera High School                 83.98         94.13%            97.04%
# ...

# %%
#bottom 5 performing schools based on overall passing
bottom_performers = school_summary.sort_values('% Overall Passing')

bottom_performers.head()
# Out:
#                       School Type Total Students   Total Budget  \
# School Name
# Rodriguez High School    District          3,999  $2,547,363.00
# Figueroa High School     District          2,949  $1,884,411.00
# Huang High School        District          2,917  $1,910,635.00
# Johnson High School      District          4,761  $3,094,650.00
# Ford High School         District          2,739  $1,763,916.00
#
#                       Per Student Budget Average Math Score  \
# School Name
# Rodriguez High School            $637.00              76.84
# Figueroa High School             $639.00              76.71
# Huang High School                $655.00              76.63
# Johnson High School              $650.00              77.07
# Ford High School                 $644.00              77.10
#
#                       Average Reading Score % Passing Math % Passing Reading  \
# School Name
# Rodriguez High School                 80.74         66.37%            80.22%
# ...

# %%
#get unique grade levels
unique_grade = student_df['grade'].unique()

unique_grade
# Out:
# array(['9th', '12th', '11th', '10th'], dtype=object)

# %%
unique_school = school_df['school_name'].unique()

unique_school
# Out:
# array(['Huang High School', 'Figueroa High School', 'Shelton High School',
#        'Hernandez High School', 'Griffin High School',
#        'Wilson High School', 'Cabrera High School', 'Bailey High School',
#        'Holden High School', 'Pena High School', 'Wright High School',
#        'Rodriguez High School', 'Johnson High School', 'Ford High School',
#        'Thomas High School'], dtype=object)

# %%
sch_grade_math = pd.DataFrame(index=unique_school, columns=unique_grade)
sch_grade_math
# Out:
#                        9th 12th 11th 10th
# Huang High School      NaN  NaN  NaN  NaN
# Figueroa High School   NaN  NaN  NaN  NaN
# Shelton High School    NaN  NaN  NaN  NaN
# Hernandez High School  NaN  NaN  NaN  NaN
# Griffin High School    NaN  NaN  NaN  NaN
# Wilson High School     NaN  NaN  NaN  NaN
# Cabrera High School    NaN  NaN  NaN  NaN
# Bailey High School     NaN  NaN  NaN  NaN
# Holden High School     NaN  NaN  NaN  NaN
# Pena High School       NaN  NaN  NaN  NaN
# Wright High School     NaN  NaN  NaN  NaN
# Rodriguez High School  NaN  NaN  NaN  NaN
# Johnson High School    NaN  NaN  NaN  NaN
# Ford High School       NaN  NaN  NaN  NaN
# Thomas High School     NaN  NaN  NaN  NaN

# %%
sch_math_group = student_df.groupby(['school_name', 'grade'])

sch_math_group.mean().head()
# Out:
#                              Student ID  reading_score  math_score
# school_name         grade
# Bailey High School  10th   20365.058918      80.907183   76.996772
#                     11th   20345.148681      80.945643   77.515588
#                     12th   20386.724708      80.912451   76.492218
#                     9th    20344.481481      81.303155   77.083676
# Cabrera High School 10th   16909.487124      84.253219   83.154506

# %%
#create bins for groupby school spending
bins = [0, 585, 615, 645, 675]

group_names = ['<$585', '$585-615', '$615-645', '$645-675']

# %%
#hold raw school summary in new var
raw_student_spend = raw_school_summary

raw_student_spend["Per Student $ Summary"] = pd.cut(raw_student_spend["Per Student Budget"], bins, labels=group_names)
raw_student_spend.head()
# Out:
#                       Average Math Score  Average Reading Score  \
# School Name
# Bailey High School             77.048432              81.033963
# Cabrera High School            83.061895              83.975780
# Figueroa High School           76.711767              81.158020
# Ford High School               77.102592              80.746258
# Griffin High School            83.351499              83.816757
#
#                       Total Students  Total Budget  Per Student Budget  \
# School Name
# Bailey High School              4976     3124928.0               628.0
# Cabrera High School             1858     1081356.0               582.0
# Figueroa High School            2949     1884411.0               639.0
# Ford High School                2739     1763916.0               644.0
# Griffin High School             1468      917500.0               625.0
#
#                       % Passing Math  % Passing Reading  % Overall Passing  \
# School Name
# ...

# %%
#groupby per student bins
raw_spend_summary = raw_student_spend.groupby('Per Student $ Summary')
raw_spend_summary.mean()
# Out:
#                        Average Math Score  Average Reading Score  \
# Per Student $ Summary
# <$585                           83.455399              83.933814
# $585-615                        83.599686              83.885211
# $615-645                        79.079225              81.891436
# $645-675                        76.997210              81.027843
#
#                        Total Students  Total Budget  Per Student Budget  \
# Per Student $ Summary
# <$585                     1592.000000  9.246042e+05          581.000000
# $585-615                  1361.500000  8.212290e+05          604.500000
# $615-645                  2961.000000  1.880208e+06          635.166667
# $645-675                  4104.333333  2.675768e+06          652.333333
#
#                        % Passing Math  % Passing Reading  % Overall Passing
# Per Student $ Summary
# <$585                       93.460096          96.610877          95.035486
# ...

# %%
#keep the needed rows
sch_spend_summary = raw_spend_summary[['Average Math Score', 'Average Reading Score', 
                                       '% Passing Math', '% Passing Reading', '% Overall Passing']].mean()

sch_spend_summary
# Out:
#                        Average Math Score  Average Reading Score  \
# Per Student $ Summary
# <$585                           83.455399              83.933814
# $585-615                        83.599686              83.885211
# $615-645                        79.079225              81.891436
# $645-675                        76.997210              81.027843
#
#                        % Passing Math  % Passing Reading  % Overall Passing
# Per Student $ Summary
# <$585                       93.460096          96.610877          95.035486
# $585-615                    94.230858          95.900287          95.065572
# $615-645                    75.668212          86.106569          80.887391
# $645-675                    66.164813          81.133951          73.649382

# %%
#format dataframe
sch_spend_summary['Average Math Score'] = sch_spend_summary['Average Math Score'].map('{:.2f}'.format)
sch_spend_summary['Average Reading Score'] = sch_spend_summary['Average Reading Score'].map('{:.2f}'.format)
sch_spend_summary['% Passing Math'] = sch_spend_summary['% Passing Math'].map('{:.2f}%'.format)
sch_spend_summary['% Passing Reading'] = sch_spend_summary['% Passing Reading'].map('{:.2f}%'.format)
sch_spend_summary['% Overall Passing'] = sch_spend_summary['% Overall Passing'].map('{:.2f}%'.format)

sch_spend_summary
# Out:
#                       Average Math Score Average Reading Score % Passing Math  \
# Per Student $ Summary
# <$585                              83.46                 83.93         93.46%
# $585-615                           83.60                 83.89         94.23%
# $615-645                           79.08                 81.89         75.67%
# $645-675                           77.00                 81.03         66.16%
#
#                       % Passing Reading % Overall Passing
# Per Student $ Summary
# <$585                            96.61%            95.04%
# $585-615                         95.90%            95.07%
# $615-645                         86.11%            80.89%
# $645-675                         81.13%            73.65%

# %%
#group merged data by type
sch_type = renamed_columns.groupby(['School Type'])
sch_type.mean()
# Out:
#              School ID  School Size  School Budget    Student ID  \
# School Type
# Charter       6.964163  1717.352468   1.024543e+06  19438.475398
# District      6.984505  4063.261195   2.611175e+06  19650.507711
#
#              Reading Score  Math Score
# School Type
# Charter          83.902821   83.406183
# District         80.962485   76.987026

# %%
#grab avg math and reading score columns
sch_type_summary = sch_type['Math Score', 'Reading Score'].mean()
sch_type_summary
# Out:
#              Math Score  Reading Score
# School Type
# Charter       83.406183      83.902821
# District      76.987026      80.962485

# %%
#count of students by type
type_student = renamed_columns['School Type'].value_counts()
type_student
# Out:
# District    26976
# Charter     12194
# Name: School Type, dtype: int64

# %%
#percent pass math by type
type_pass_math = (renamed_columns[renamed_columns['Math Score'] >= 70].groupby('School Type')['Math Score'].count()) * 100 / type_student
type_pass_math
# Out:
# Charter     93.701821
# District    66.518387
# dtype: float64

# %%
#percent pass reading by type
type_pass_reading = (renamed_columns[renamed_columns['Reading Score'] >= 70].groupby('School Type')['Reading Score'].count()) * 100 / type_student
type_pass_reading
# Out:
# Charter     96.645891
# District    80.905249
# dtype: float64

# %%
#percent pass overall by type
type_pass_overall = (type_pass_math + type_pass_reading) / 2
type_pass_overall
# Out:
# Charter     95.173856
# District    73.711818
# dtype: float64

# %%
#type dataframe
sch_type_summary['% Passing Math'] = type_pass_math
sch_type_summary['% Passing Reading'] = type_pass_reading
sch_type_summary['% Overall Passing'] = type_pass_overall

sch_type_summary
# Out:
#              Math Score  Reading Score  % Passing Math  % Passing Reading  \
# School Type
# Charter       83.406183      83.902821       93.701821          96.645891
# District      76.987026      80.962485       66.518387          80.905249
#
#              % Overall Passing
# School Type
# Charter              95.173856
# District             73.711818

# %%
#rename columns
type_summary = sch_type_summary.rename(columns={'Math Score': 'Average Math Score',
                                                'Reading Score': 'Average Reading Score'})

type_summary
# Out:
#              Average Math Score  Average Reading Score  % Passing Math  \
# School Type
# Charter               83.406183              83.902821       93.701821
# District              76.987026              80.962485       66.518387
#
#              % Passing Reading  % Overall Passing
# School Type
# Charter              96.645891          95.173856
# District             80.905249          73.711818

# %%
#format dataframe
type_summary['Average Math Score'] = type_summary['Average Math Score'].map('{:.2f}'.format)
type_summary['Average Reading Score'] = type_summary['Average Reading Score'].map('{:.2f}'.format)
type_summary['% Passing Math'] = type_summary['% Passing Math'].map('{:.2f}%'.format)
type_summary['% Passing Reading'] = type_summary['% Passing Reading'].map('{:.2f}%'.format)
type_summary['% Overall Passing'] = type_summary['% Overall Passing'].map('{:.2f}%'.format)

type_summary
# Out:
#             Average Math Score Average Reading Score % Passing Math  \
# School Type
# Charter                  83.41                 83.90         93.70%
# District                 76.99                 80.96         66.52%
#
#             % Passing Reading % Overall Passing
# School Type
# Charter                96.65%            95.17%
# District               80.91%            73.71%
